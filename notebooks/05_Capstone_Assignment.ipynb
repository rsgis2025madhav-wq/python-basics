# %% [markdown]
# <a href="https://colab.research.google.com/github/rsgis2025madhav-wq/python-basics/blob/main/notebooks/05_Capstone_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Full Capstone Assignment — Python for Earth System & Remote Sensing**
#
# This Capstone Assignment integrates all major skills from Notebooks **01 → 04**:
#
# - Python fundamentals
# - Lists, loops, conditions
# - Functions & plotting
# - NumPy
# - xarray
# - NetCDF
# - Scientific interpretation
#
# **This assignment is designed to be completed over multiple days** and tests understanding, reasoning, coding clarity, and scientific interpretation.

# %% [markdown]
# ---
# # **Section 0 — Setup (Required)**
#
# Run the cell below to import the scientific Python libraries you need for the assignment.

# %%
import numpy as np
import matplotlib.pyplot as plt
import xarray as xr
# %matplotlib inline

# %% [markdown]
# ---
# # **Section 1 — Python Fundamentals (Notebook 01)**
#
# ### **Q1.1 — Arithmetic & Variables**
# Create:
# - `a = 12`
# - `b = 4.7`
# - `c = -3`
#
# Compute and print:
# 1. `a + b`
# 2. `a * c`
# 3. `(a + b) / c`
#
# Use f-strings to print meaningful messages.

# %%
a = 12
b = 4.7
c = -3
print("a + b =", a + b)
print("a * c =", a * c)
print("(a + b) / c =", (a + b) / c)
# Out:
# a + b = 16.7
# a * c = -36
# (a + b) / c = -5.566666666666666

# %% [markdown]
# ### **Q1.2 — Basic Statistics**
# Given:
# ```python
# sst = [27.9, 28.0, 28.4, 28.6, 28.8, 29.1, 28.7, 28.3, 27.8]
# ```
#
# Compute:
# - Mean
# - Median
# - Minimum
# - Maximum
# - Standard deviation
#
# Print with clear labels.

# %%
# Q1.2
sst = [27.9,28.0,28.4,28.6,28.8,29.1,28.7,28.3,27.8]
import numpy as np
print("Mean =", np.mean(sst))
print("median =", np.median(sst))
print("min", min(sst))
print("max", max(sst))
print("std", np.std(sst))
# Out:
# Mean = 28.400000000000002
# median = 28.4
# min 27.8
# max 29.1
# std 0.416333199893227

# %% [markdown]
# ---
# # **Section 2 — Lists, Loops, and Conditions (Notebook 02)**
#
# ### **Q2.1 — Day-wise SST Printing**
# Using the `sst` list from Q1.2, print:
#
# ```
# Day 1: value
# Day 2: value
# ...
# ```

# %%
# Q2.1
sst = [27.9, 28.0, 28.4, 28.6, 28.8, 29.1, 28.7, 28.3, 27.8]
import xarray as xr
for i in range(len(sst)):
  print("Day", i + 1, ":", sst[i])
# Out:
# Day 1 : 27.9
# Day 2 : 28.0
# Day 3 : 28.4
# Day 4 : 28.6
# Day 5 : 28.8
# Day 6 : 29.1
# Day 7 : 28.7
# Day 8 : 28.3
# Day 9 : 27.8

# %% [markdown]
# ### **Q2.2 — Classification**
# Classify each SST into:
# - **HOT** (> 29)
# - **WARM** (28–29)
# - **NORMAL** (< 28)
#
# Print classification for each day.
# At the end, print counts for each category.

# %%
sst = [27.9, 28.0, 28.4, 28.6, 28.8, 29.1, 28.7, 28.3, 27.8]
print(len(sst))
hot_sst = []
warm_sst = []
normal_sst = []
for i in range(len(sst)):
  temp = sst[i]
  if temp > 29:
    hot_sst.append(temp)
  if temp > 28:
    warm_sst.append(temp)
  if temp < 28 and temp <= 29:
    normal_sst.append(temp)
print("HOT:", (hot_sst))
print("WARM:", (warm_sst))
print("NORMAL:", (normal_sst))
# Out:
# 9
# HOT: [29.1]
# WARM: [28.4, 28.6, 28.8, 29.1, 28.7, 28.3]
# NORMAL: [27.9, 27.8]

# %% [markdown]
# ### **Q2.3 — Rolling 3-day Mean**
# Compute a 3-day rolling mean using loops (without NumPy).
# Example output:
# ```
# Mean Day1-3: ...
# Mean Day2-4: ...
# ...
# ```

# %%
# Q2.3
sst = [27.9, 28.0, 28.4, 28.6, 28.8, 29.1, 28.7, 28.3, 27.8]
for i in range(len(sst)-2):
  temp = (sst[i] + sst[i+1] + sst[i+2])/3

  print("Mean Day", i+1, "-", i+3, ":", temp)
# Out:
# Mean Day 1 - 3 : 28.099999999999998
# Mean Day 2 - 4 : 28.333333333333332
# Mean Day 3 - 5 : 28.599999999999998
# Mean Day 4 - 6 : 28.833333333333332
# Mean Day 5 - 7 : 28.86666666666667
# Mean Day 6 - 8 : 28.7
# Mean Day 7 - 9 : 28.266666666666666

# %% [markdown]
# ---
# # **Section 3 — Functions, Arrays, and Plotting (Notebook 03)**
#
# ### **Q3.1 — Function: Celsius → Kelvin**
# Define:
# ```python
# def c_to_k(T_c):
#     ...
# ```
# Test on 5 sample values.

# %%
# Q3.1
def c_to_k(T_c):
  T_k = T_c + 273.15
  return T_k
print(c_to_k(20),"K",c_to_k(26),"K",c_to_k(22),"K",c_to_k(23),"K",c_to_k(24),"K")
# Out:
# 293.15 K 299.15 K 295.15 K 296.15 K 297.15 K

# %% [markdown]
# ### **Q3.2 — Function: Anomaly Computation**
# Define:
# ```python
# def compute_anomaly(arr):
#     ...
# ```
# Return array − mean.
# Test using `sst`.

# %%
# Q3.2
import numpy as np
sst = [27.9, 28.0, 28.4, 28.6, 28.8, 29.1, 28.7, 28.3, 27.8]
sst = np.array(sst)
def compute_anomaly(arr):
  mean = np.mean(sst)
  print(arr)
  print(arr-mean)
  return arr-mean
compute_anomaly(sst)
# Out:
# [27.9 28.  28.4 28.6 28.8 29.1 28.7 28.3 27.8]
# [-5.00000000e-01 -4.00000000e-01 -3.55271368e-15  2.00000000e-01
#   4.00000000e-01  7.00000000e-01  3.00000000e-01 -1.00000000e-01
#  -6.00000000e-01]
# array([-5.00000000e-01, -4.00000000e-01, -3.55271368e-15,  2.00000000e-01,
#         4.00000000e-01,  7.00000000e-01,  3.00000000e-01, -1.00000000e-01,
#        -6.00000000e-01])

# %% [markdown]
# ### **Q3.3 — Convert to NumPy + Plot**
#
# 1. Convert `sst` to a NumPy array
# 2. Compute anomalies
# 3. Create a line plot of SST
# 4. Create a second plot of anomalies
# 5. Include:
#    - Titles
#    - Axis labels
#    - Grid
#    - A horizontal zero line for anomalies

# %%
# Q3.3
import matplotlib.pyplot as plt
import numpy as np
sst = [27.9, 28.0, 28.4, 28.6, 28.8, 29.1, 28.7, 28.3, 27.8]
sst_np = np.array(sst)
anomalies = compute_anomaly(sst)
plt.plot(sst, marker='*')
plt.title("SST")
plt.xlabel("Day")
plt.ylabel("SST")
plt.grid()
plt.show()
plt.plot(anomalies)
plt.title("Anomalies")
plt.xlabel("Day")
plt.ylabel("Anomalies")
plt.grid()
plt.axhline(y=0, color='r', linestyle='-')
plt.show()
# Out:
# [27.9, 28.0, 28.4, 28.6, 28.8, 29.1, 28.7, 28.3, 27.8]
# [-5.00000000e-01 -4.00000000e-01 -3.55271368e-15  2.00000000e-01
#   4.00000000e-01  7.00000000e-01  3.00000000e-01 -1.00000000e-01
#  -6.00000000e-01]

# %% [markdown]
# ---
# # **Section 4 — NetCDF + xarray: Remote Sensing Dataset (Notebook 04)**
#
# A small SST NetCDF file will be downloaded automatically.

# %%
# Auto-download NetCDF file
import requests, os
import xarray as xr

url = "https://raw.githubusercontent.com/EarthSystem-Science-Lab/python-basics/main/data/data_sst.nc"
local = "data_sst.nc"

if not os.path.exists(local):
    r = requests.get(url)
    open(local,"wb").write(r.content)

ds = xr.open_dataset(local)
ds
# Out:
# <xarray.Dataset> Size: 7kB
# Dimensions:  (time: 7, lat: 11, lon: 11)
# Coordinates:
#   * time     (time) datetime64[ns] 56B 2020-01-01 2020-01-02 ... 2020-01-07
#   * lat      (lat) float64 88B 10.0 11.0 12.0 13.0 14.0 ... 17.0 18.0 19.0 20.0
#   * lon      (lon) float64 88B 70.0 71.0 72.0 73.0 74.0 ... 77.0 78.0 79.0 80.0
# Data variables:
#     sst      (time, lat, lon) float64 7kB ...
# Attributes:
#     title:    Sample synthetic SST dataset for teaching
#     source:   Generated in Python for teaching by Arjun's EarthSystem-Science...
#     history:  Created as a small example NetCDF file for Notebook 4

# %% [markdown]
# ### **Q4.1 — Dataset Exploration**
# Print:
# - Dimensions
# - Coordinates
# - Variables
# - Global attributes

# %%
# Q4.1
dimensions = ds.dims
coordinates = ds.coords
variables = ds.data_vars
global_attributes = ds.attrs
print("Dimensions:", dimensions)
print("coordinates:", coordinates)
print("variables:", variables)
print("global_attributes:", global_attributes)
# Out:
# Dimensions: FrozenMappingWarningOnValuesAccess({'time': 7, 'lat': 11, 'lon': 11})
# coordinates: Coordinates:
#   * time     (time) datetime64[ns] 56B 2020-01-01 2020-01-02 ... 2020-01-07
#   * lat      (lat) float64 88B 10.0 11.0 12.0 13.0 14.0 ... 17.0 18.0 19.0 20.0
#   * lon      (lon) float64 88B 70.0 71.0 72.0 73.0 74.0 ... 77.0 78.0 79.0 80.0
# variables: Data variables:
#     sst      (time, lat, lon) float64 7kB ...
# global_attributes: {'title': 'Sample synthetic SST dataset for teaching', 'source': "Generated in Python for teaching by Arjun's EarthSystem-Science-Lab", 'history': 'Created as a small example NetCDF file for Notebook 4'}

# %% [markdown]
# ### **Q4.2 — Statistics on `sst`**
# Compute and print:
# - Global mean
# - Min
# - Max

# %%
# Q4.2
import numpy as np
import xarray as xr
ds = xr.open_dataset("data_sst.nc")
sst = ds.sst
print(sst)
print("Global mean:", np.mean(sst))
print("Min:", np.min(sst))
print("Max:", np.max(sst))
# Out:
# <xarray.DataArray 'sst' (time: 7, lat: 11, lon: 11)> Size: 7kB
# [847 values with dtype=float64]
# Coordinates:
#   * time     (time) datetime64[ns] 56B 2020-01-01 2020-01-02 ... 2020-01-07
#   * lat      (lat) float64 88B 10.0 11.0 12.0 13.0 14.0 ... 17.0 18.0 19.0 20.0
#   * lon      (lon) float64 88B 70.0 71.0 72.0 73.0 74.0 ... 77.0 78.0 79.0 80.0
# Attributes:
#     long_name:  Sea Surface Temperature
#     units:      degree_Celsius
# Global mean: <xarray.DataArray 'sst' ()> Size: 8B
# array(27.2)
# Attributes:
#     long_name:  Sea Surface Temperature
#     units:      degree_Celsius
# Min: <xarray.DataArray 'sst' ()> Size: 8B
# array(26.)
# Attributes:
#     long_name:  Sea Surface Temperature
#     units:      degree_Celsius
# Max: <xarray.DataArray 'sst' ()> Size: 8B
# array(28.4)
# Attributes:
#     long_name:  Sea Surface Temperature
#     units:      degree_Celsius

# %% [markdown]
# ### **Q4.3 — Time-Mean Map**
# 1. Compute `sst_mean_time = ds.sst.mean(dim='time')`
# 2. Plot a colour map (lat vs lon)
# 3. Add labels, title, and colorbar

# %%
# Q4.3
import matplotlib.pyplot as plt
import numpy as np
import xarray as xr
ds = xr.open_dataset("data_sst.nc")
sst = ds.sst
sst_mean_time = sst.mean(dim='time')
plt.imshow(sst_mean_time, cmap='jet')
plt.colorbar()
plt.title("Time-mean SST")
plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.show()

# %% [markdown]
# ### **Q4.4 — Time Series at a Point**
# Choose a latitude & longitude inside file domain.
# Extract nearest time series and plot it.
#
# Add axis labels and title.

# %%
# Q4.4
import matplotlib.pyplot as plt
import numpy as np
import xarray as xr
ds = xr.open_dataset("data_sst.nc")
sst = ds.sst
plt.plot(sst.time, sst[:, 10, 10])
plt.xlabel("Time")
plt.ylabel("SST")
plt.title("Time series at (10, 10)")
plt.show()

# %% [markdown]
# ---
# # **Section 5 — Capstone Scientific Interpretation**
#
# Write **10–12 sentences** answering:
#
# 1. What spatial patterns do you observe in your time-mean SST map?
# 2. Does the time series at your chosen point indicate warming/cooling or variability?
# 3. What physical processes (mixing, stratification, insolation, currents, monsoon) could explain the patterns?
# 4. How do your anomaly results relate to the NetCDF dataset behavior?
# 5. How would these methods apply to real satellite (Sentinel-3/OLCI) or Argo data?
#
# Write your answer below.

# %% [markdown]
# 1. The SST gradually increases from day 1 and peaks at day 5 reaching 29 C, the declines slowly as reaching day 7.
# 2. SST shows a consistent increase over the period from January 1st to January 7th, 2020. This indicates a warming trend at that specific location.
# 3.
